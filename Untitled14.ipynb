# %% [markdown]
# <a href="https://colab.research.google.com/github/subshr4/subshr4/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Subani Shrestha

# %% [markdown]
# 1.

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-68dabba4-76c3-41e9-9e6a-e43c53db4d0d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68dabba4-76c3-41e9-9e6a-e43c53db4d0d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bar1.jpg to bar1.jpg

# %%
Image('bar1.jpg',
      width=400)

# %% [markdown]
# gathered from ( https://symposium.foragerone.com/okrd22/presentations/37658 ) on 03/23/2022

# %% [markdown]
# On the graphic, we see one bar as 20 mm and the other as 30 mm (measures with a ruler against the screen!). We see this as:
#
#
# (30-20)/20 = 50

# %%
p=(30-20)/20 
p*100
# Out:
# 50.0

# %%
import pandas as pa

x = [25,50]

df = pa.DataFrame({'rate':x})

df.plot.bar()

# %%
percentchange = (50-25)/25

percentchange*100
# Out:
# 100.0

# %% [markdown]
# So the lie factor is:
#
# 50/100

# %%
50/100
# Out:
# 0.5

# %% [markdown]
# A lie factor of 0.5.

# %% [markdown]
# 2.

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c9971228-4341-438f-8554-b65c8a3273a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9971228-4341-438f-8554-b65c8a3273a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bar2.jpg to bar2.jpg

# %%
Image('bar2.jpg',
      width=300)

# %% [markdown]
# gathered from (https://symposium.foragerone.com/okrd22/presentations/36968) on 03/23/**2022**

# %% [markdown]
# On the graphic, we see one bar as 30 mm and the other as 36 mm (measures with a ruler against the screen!). We see this as:
#
#
# (36-30)/30 = 20

# %%
import pandas as pa

x = [30,36]

df = pa.DataFrame({'rate':x})

df.plot.bar()

# %%
percentchange = (72-62)/62

percentchange*100
# Out:
# 16.129032258064516

# %% [markdown]
# So, the lie factor is
#
# 20/16.12

# %%
20/16.12
# Out:
# 1.2406947890818858

# %% [markdown]
# A lie factor of 1.240

# %% [markdown]
# 3.

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-374dcc5c-322b-4c09-be87-ae63079e939d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-374dcc5c-322b-4c09-be87-ae63079e939d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bar3.jpg to bar3.jpg

# %%
Image('bar3.jpg',
      width=300)

# %% [markdown]
# gathered from ( https://symposium.foragerone.com/okrd22/presentations/37502 ) on 03/23/2022

# %% [markdown]
# On the graphic, we see one bar as 27 mm and the other as 30 mm (measures with a ruler against the screen!). We see this as:
#
#
# (30-27)/27= 11.11

# %%
import pandas as pa

x = [27,30]

df = pa.DataFrame({'rate':x})

df.plot.bar()

# %%
percentchange = (19-17.3)/17.3

percentchange*100
# Out:
# 9.826589595375717

# %% [markdown]
# So, the lie factor is
#
# 11.11/9.82

# %%
11.11/9.82
# Out:
# 1.131364562118126

# %% [markdown]
# The lie factor of 1.131
