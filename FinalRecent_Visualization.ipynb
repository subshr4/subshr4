# %% [markdown]
# <a href="https://colab.research.google.com/github/subshr4/subshr4/blob/main/FinalRecent_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Subani Shrestha**
#
# **Data Processing and Visualization (CPSMA-4313-01)**
#
# **Dr. Nicholas Jacob**

# %% [markdown]
# # Recent Visualizations

# %% [markdown]
# # The Rising Speed Of Technology Adoption

# %% [markdown]
# **1.**
# I have selected the "Rising speed of technology adoption" as my timely topic for this recent visualization project.
#
# Here, the first graph shows how the US households are using different technologies like microwave, television, computer, washer, internet, and many more from 1903 to 2019. The second graph shows the adoption rates for the household appliances and products today that we would consider pretty essential, over a period of more than 120 years. The third graph shows new adoption speed of different new technologies like computer, microcomputer, internet, and many more from 1951 to 2016.
#
# "The Rising Speed of Technology Adoption" is a timely topic as it shows how old or new technology are being adopted in US household since 1900 till now. Technology has been rising day by day. These graphs also allows you to compare the adoption rates of new technologies over the period of more than a century. These graph also shows how the new consumers are connected, fast-acting, and not afraid to adopt the new technologies that can quickly impact their lives for the better.
#
#
# Source:
#
#  https://www.visualcapitalist.com/rising-speed-technological-adoption/

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-78dd4f60-d078-495d-8f46-0f20c8f1eade" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78dd4f60-d078-495d-8f46-0f20c8f1eade">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mapp3.jpg to mapp3.jpg

# %% [markdown]
# # Graph 1 (Different technologies used by US household)

# %%
Image("mapp3.jpg",width=500)

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-206edb73-1a59-4c49-aed9-401cf81bf428" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-206edb73-1a59-4c49-aed9-401cf81bf428">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mapp1.jpg to mapp1.jpg

# %% [markdown]
# # Graph 2 (Adoption rate of old technologies used in past from 1890-2014)

# %%
Image("mapp1.jpg",width=500)

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-07971793-66e1-449b-b60d-cf8c24fd589a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07971793-66e1-449b-b60d-cf8c24fd589a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mapp2.jpg to mapp2.jpg

# %% [markdown]
# # Graph 3 (Adoption rate of new technologies from 1951 to 2015)

# %%
Image("mapp2.jpg",width=500)

# %% [markdown]
# # 2. Reference to all three graph

# %% [markdown]
# **Data published by:**
#
# Horace Dediu; Comin and Hobijn (2004) and others
#
# **Data publisher's source:**
#
# Scholarly work, census data
#
# **Link**
#
# http://www.asymco.com/author/asymco/
# http://www.nber.org/data/chat/

# %% [markdown]
# Following is the reference for the graph that shows adoption rate for different technologies that have been popular since past.

# %% [markdown]
# https://www.visualcapitalist.com/wp-content/uploads/2018/02/old-tech.jpg

# %% [markdown]
# Following is the reference for the graph that show adoption rate for different new technologies and old technologies removed.
#
# https://www.visualcapitalist.com/wp-content/uploads/2018/02/newer-tech.jpg

# %% [markdown]
# 3. Graph 1:
#
# There are several things to notice in this graph. It is a time series graph. It represents uses of different technologies in US household since 1903 to 2016. Here each technologies are highlighted using different color. We can also add and remove  technology to see its adoption rate by using the add technology option. For example: In the following graph I unselected all the technology except Dishwasher. It clearly shows how its adoption rapidly increased after 1978 from 41.90% to 61.40%. Similarly, we can search adoption rate of different technology. In this way it provides different ideas and provide truth of the data. So this is an excellent graph. There is no any error but I wish this graph could also have x-label (Rate of Adoption) and y-label (Year).

# %% [markdown]
# Graph 2:
#
# This is also a time series graph. The second visualization is labeled as "A Blast From The Past" as it shows adoption rates for the household appliances and products today that we would consider pretty essential, over a period of more than 120 years. Here x axis shows the year from 1890 to 2014 whereas y axis shows the rate of adoption. All the technology are presented by the help of different colors. It is clear and easy to understand too. This is also an excellent graph.

# %% [markdown]
# Graph 3:
#
# This is also a time series graph. It is labeled as "New Adoption Speed" as it shows how fastly the new technology are being adopted by US household in around 65 years from 1951 to 2016. Standing out most on the chart is the tablet computer, which went from nearly 0% to 50% adoption in five years or so. Here also all technologies are presented by different color. It is also clear to read and understand. So, this is also an excellent graph.

# %% [markdown]
# (d) (30 points) An explanation of why the visualizations helped to improve the article is included. Be sure to consider any bias of the organization.

# %% [markdown]
# For sure, all this visualizations have helped to make this article more attractive, and clear to recognize the emerging trends and changes. Because of this time series graph we are able to interpret adoption rate of vast quantities of technologies in a clear way and draw conclusion as well. If there was no visualization the article would have been more longer and hard to understand which makes it more hard to decide anything. But this visualization helps speed up faster descisions making process.  We can also add and remove technology to see its adoption rate by using the add technology option which is included in the visualization. For example, I unselected all the technology except Dishwasher. It clearly shows how its adoption rapidly increased after 1978 from 41.90% to 61.40%. Similarly, we can search adoption rate of different technology.

# %% [markdown]
# (e) (10 points) Similarities and differences between the visualizations are examined.

# %% [markdown]
# Similarities:
#
# 1. All the visualizations provided are time series graph.
# 2. They all have x axis as year and y axis as rate of adoption.
# 3. They all have technology represented by different color to make the graph look more clear.
#
#
# Differences:
#
# 1. The first graph shows adoption rate of both new and old technology in US household till 2010. The second graph shows the adoption rate of old technology from 1890 to 2014 whereas the last graph shows the adoption rate of new technology from 1951 to 2016.
#
# 2. It shows how the new technologies are being fastly adopted in comparison to old technologies.
#
# 3. The first graph has an option to add or remove technology whereas the other two graphs does not have that option.
