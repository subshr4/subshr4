# %% [markdown]
# <a href="https://colab.research.google.com/github/subshr4/subshr4/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Subani Shrestha

# %% [markdown]
# **Graphical Excellence (  John Snow's map of cholera outbreak in 1854 )**

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-289a9fe4-3875-4226-ac26-66192f3a6b80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-289a9fe4-3875-4226-ac26-66192f3a6b80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mapp.jpg to mapp.jpg

# %%
Image('mapp.jpg',
      width=600)

# %% [markdown]
#  John Snow observed that cholera occurred almost entirely among those who lived near the water pumps. So, he had the handle of the contaminated pump removed. This observation of map where deaths were marked by dots and location were mapped by crosses helped to  saved many lives.
#
#
# Gathered from ( https://www.ph.ucla.edu/epi/snow/mapsbroadstreet.html) on 03/21/2022
