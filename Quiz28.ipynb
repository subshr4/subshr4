# %% [markdown]
# <a href="https://colab.research.google.com/github/subshr4/subshr4/blob/main/Quiz28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Subani Shrestha

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv')

data.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %%
ax = sns.scatterplot(data = df, x = 'anaerobic', y = 'aerobic')
ax.set(title = "Length vs Width",
       xticks = [x for x in range(0,5,10)])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-2130383f2e37> in <module>()
# ----> 1 ax = sns.scatterplot(data = df, x = 'anaerobic', y = 'aerobic')
#       2 ax.set(title = "Length vs Width",
#       3        xticks = [x for x in range(0,5,10)])
#       4 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')  # to get seaborn scatter plot

# read the csv file to extract data

data = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv')
distance = data['distance']
calories = data['calories']
workout_type = data['workout_type']


plt.scatter(distance, calories, s=30, alpha=0.6, linewidth=1)

plt.title('distance vs calories')
plt.xlabel('distance')
plt.ylabel('calories')

plt.show()

# %%
import seaborn
plt.scatter(distance, calories, s=30, alpha=0.6, edgecolor='red',linewidth=1)
                   

plt.title('distance vs calories')
plt.xlabel('distance')
plt.ylabel('calories')

plt.show()

# %%
plt.scatter(distance,calories, s=100, alpha=0.6, edgecolor='black', linewidth=1, cmap='blue')
colorsbar = plt.colorbar()
colorsbar.set_label('Rating (1-10)')
plt.tight_layout()
plt.show()
